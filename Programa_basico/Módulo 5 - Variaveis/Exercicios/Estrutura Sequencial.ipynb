# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alô Mundo!")
# Out:
# Alô Mundo!

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input("Digite um numero: "))

print(f'O número informado foi {numero}')
# Out:
# O número informado foi 10

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero_1 = int(input("Digite um número inteiro:"))
numero_2 = int(input("Digite outro número inteiro:"))

print(f'A soma do número {numero_1} e do {numero_2} é {numero_1+numero_2}')
# Out:
# A soma do númeor 50 e do 100 é 150

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota_1 = float(input('Digite a nota do 1° Bimestre: '))
nota_2 = float(input('Digite a nota do 2° Bimestre: '))
nota_3 = float(input('Digite a nota do 3° Bimestre: '))
nota_4 = float(input('Digite a nota do 4° Bimestre: '))

print("A média dos 4 bimestres é igual a",(nota_1+nota_2+nota_3+nota_4)/4)
# Out:
# A média dos 4 bimestres é igual a 8.75

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input('Digite a distância em metros(m):'))

print(f'{metros} metros equivale a {metros*100} centimetros(cm)')
# Out:
# 1.5 metros equivale a 150.0 centimetros(cm)

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
comprimento = float(input("Digite o comprimento do seu apartamento, em metros:"))
largura = float(input("Digite a largura do seu apartamento, em metros: "))

print("O seu apartamento tem {0} metros quadrados ou {0} m²".format(comprimento*largura))
# Out:
# O seu apartamento tem 2000.0 metros quadrados ou 2000.0 m²

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
horas = float(input("Quantas horas você trabalhou no mês? "))
valor_hora = float(input("Quanto você ganha por hora? "))

print(f'O valor que você ganhou esse mês com as horas trabalhadas foi de R${horas*valor_hora}')
# Out:
# O valor que você ganhou esse mês com as horas trabalhadas foi de R$2000.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
Fahrenheit = float(input('Digite a temperatura em graus Fahrenheit(F): '))

print('Isso equivale a {}° Celcius'.format((Fahrenheit-32)*5/9))
# Out:
# Isso equivale a 107.55555555555556° Celcius

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
Celcius = float(input('Digite a temperatura em graus Celcius(C): '))

print('Isso equivale a {}° Fahrenheit'.format((Celcius*9/5)+32))
# Out:
# Isso equivale a 199.9999999999994° Fahrenheit

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Digite sua altura: '))

peso_ideal = 72.7*altura - 58

print('Seu peso ideial é: ' + str(peso_ideal))
# Out:
# Seu peso ideial é: 69.22500000000001

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
sexo = str(input("Qual é o seu sexo? Maculino(M) ou Feminino (F):"))

if sexo not in ["M","m","F","f"]:
    print("Sexo invalido")
else:
    altura = float(input("Digite a sua altura: "))
    if sexo == "M" or sexo == "m":
        peso = 72.7*altura - 58
    elif sexo == "F" or sexo == "f":
        peso = 62.1*altura - 44.7

    print('Seu peso ideial é: ' + str(peso))
# Out:
# Seu peso ideial é: 17.4

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
horas = float(input("Quantas horas você trabalhou no mês? "))
valor_hora = float(input("Quanto você ganha por hora? "))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = horas*valor_hora
print(f'O seu salário bruto equivale a R${salario_bruto}')
# Out:
# O seu salário bruto equivale a R$1900.0

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
Ir = salario_bruto*11/100
print("O valor pago de imposto de rende é de {}".format(Ir))
# Out:
# O valor pago de imposto de rende é de 209.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
Inss = salario_bruto*8/100
print("O valor pago de INSS é de {}".format(Inss))
# Out:
# O valor pago de INSS é de 152.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
Sindicato = salario_bruto*5/100
print("O valor pago de Sindicato é de {}".format(Sindicato))
# Out:
# O valor pago de Sindicato é de 95.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
Descontos = Ir+Inss+Sindicato
Salario_liquido = salario_bruto-Descontos

print(f'O seu salário liquido equivale a R${Salario_liquido} pois, {Descontos} reais foram de impostos.')
# Out:
# O seu salário liquido equivale a R$1444.0 pois, 456.0 reais foram de impostos.

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
Area = float(input("Informe a area que será pintada em metros quadrados(m²):"))

Latas_Gastas = round((Area/3)/18) 

Valor_Tinta = Latas_Gastas*80

print(f'Você comprará {Latas_Gastas} lata(s) de tinta, será necessario um gasto de {Valor_Tinta} reias')
# Out:
# Você comprará 1 latas de tinta, será necessario um gasto de 80 reias

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
Arquivo = float(input("Digite o tamanho do arquivo em Mb:"))
Velocidade = float(input("Digite a velocidade do link de internet em Mbps:"))

tempo = round((Arquivo*8)/Velocidade/60, 1)

print(f"Você gastará aproximadamente {tempo} minutos")
# Out:
# Você gastará aproximadamente 13.3 minutos
